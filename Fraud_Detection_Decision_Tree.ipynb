# %%
import pandas as pd
import numpy as np

# %%
df_in=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Train_Inpatientdata-1542865627584.csv')

# %%
df_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt        ...         ClmDiagnosisCode_7  \
# 0            NaN  2009-04-12        ...                       2724
# 1            NaN  2009-08-31        ...                        NaN
# ...

# %%
df_bene=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Train_Beneficiarydata-1542865627584.csv')
df_out=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Train_Outpatientdata-1542865627584.csv')
df_op=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Train-1542865627584.csv')

# %%
df_op.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# converting Yes=1, No=0

# %%
lb_make = LabelEncoder()
df_op['PotentialFraud']=lb_make.fit_transform(df_op['PotentialFraud'])
df_op.head()
# Out:
#    Provider  PotentialFraud
# 0  PRV51001               0
# 1  PRV51003               1
# 2  PRV51004               0
# 3  PRV51005               1
# 4  PRV51007               0

# %%
df_in.shape
# Out:
# (40474, 30)

# %%
df_bene.shape
# Out:
# (138556, 25)

# %%
bene_in=pd.merge(df_in, df_bene, how='left', on='BeneID')
bene_in.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt          ...          ChronicCond_Depression  \
# 0            NaN  2009-04-12          ...                               1
# 1            NaN  2009-08-31          ...                               1
# ...

# %%
bene_in.shape
# Out:
# (40474, 54)

# %%
#export_bene_in_csv = bene_in.to_csv (r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\export_bene_in.csv', index = None, header=True)

# %%
bene_in_prov=pd.merge(bene_in, df_op, how='left', on='Provider')
bene_in_prov.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt      ...       ChronicCond_Diabetes  \
# 0            NaN  2009-04-12      ...                          1
# 1            NaN  2009-08-31      ...                          1
# ...

# %%
#export_bene_in_prov_csv = bene_in_prov.to_csv (r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\export_bene_in_prov.csv', index = None, header=True)

# %%
variables=['BeneID','ClaimID','ClaimStartDt','ClaimEndDt','InscClaimAmtReimbursed','AttendingPhysician','OperatingPhysician','OtherPhysician','AdmissionDt','DeductibleAmtPaid','DischargeDt','DOB','DOD',
'Race','State','County','NoOfMonths_PartACov','NoOfMonths_PartBCov','IPAnnualReimbursementAmt','IPAnnualDeductibleAmt','OPAnnualReimbursementAmt','OPAnnualDeductibleAmt']

# %%
fina_data_in=bene_in_prov.drop(variables, axis=1)
fina_data_in.shape
# Out:
# (40474, 33)

# %%
fina_data_in.columns.values
# Out:
# array(['Provider', 'ClmAdmitDiagnosisCode', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'Gender', 'RenalDiseaseIndicator',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'PotentialFraud'], dtype=object)

# %%
fina_data_in['RenalDiseaseIndicator']=fina_data_in['RenalDiseaseIndicator'].replace('Y',1)

# %%
fina_data_in.RenalDiseaseIndicator.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: RenalDiseaseIndicator, dtype: object

# %%
fina_data_in.head()
# Out:
#    Provider ClmAdmitDiagnosisCode DiagnosisGroupCode ClmDiagnosisCode_1  \
# 0  PRV55912                  7866                201               1970
# 1  PRV55907                  6186                750               6186
# 2  PRV56046                 29590                883              29623
# 3  PRV52405                   431                067              43491
# 4  PRV56614                 78321                975                042
#
#   ClmDiagnosisCode_2 ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0               4019               5853               7843               2768
# 1               2948              56400                NaN                NaN
# 2              30390              71690              34590              V1581
# 3               2762               7843              32723              V1041
# 4               3051              34400               5856              42732
#
#   ClmDiagnosisCode_6 ClmDiagnosisCode_7       ...        \
# ...

# %%
#df[cols]=df[cols].fillna(0)  or df.loc[:,'a':'c'] = df.loc[:,'a':'c'].fillna(0)

# %%
cols=['Provider', 'ClmAdmitDiagnosisCode', 'DiagnosisGroupCode',
 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
 'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
 'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
 'ClmProcedureCode_6', 'Gender', 'RenalDiseaseIndicator',
 'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
 'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
 'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
 'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
 'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
 'ChronicCond_stroke', 'PotentialFraud']

# %%
fina_data_in[cols]=fina_data_in[cols].fillna(0)   #filling all na wth 0

# %%
#res=fina_data_in.DiagnosisGroupCode.split()

# %%
#x = open("DiagnosisGroupCode.txt","w+")

# %%
#for i in fina_data_in.DiagnosisGroupCode:
#    x.write(str(i))
#    x.write("\n")

# %%
#x.close()

# %%
#x = open("DiagnosisGroupCode.txt","r")

# %%
#contents=pd.read_table('DiagnosisGroupCode.txt',names=('A'))

# %%
#contents.head()

# %%
#import re
#col = str(contents.A)
#x_DiagnosisGroupCode = re.sub("\AO", "1000", col)

# %%
#fina_data_in['DiagnosisGroupCode1']=x_DiagnosisGroupCode

# %%
#export_contents_csv = fina_data_in.to_csv (r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\export_fina_data_in2.csv', index = None, header=True)

# %%
#import re

#z = re.search('[a-zA-Z]', col)
#print(z)

# %%
#data = fina_data_in.set_index("DiagnosisGroupCode")
#data.head()
#x_DiagnosisGroupCode=pd.DataFrame(data)

# %%
# To delete rows with OTH
#x_DiagnosisGroupCode_index = fina_data_in[fina_data_in['DiagnosisGroupCode']=='OTH'].index
#x=fina_data_in.drop(x_DiagnosisGroupCode_index, inplace = True) 
#print(x)

# %%
#x=pd.DataFrame(x)
#x.head()
#print(x)

# %%
export_contents_csv = fina_data_in.to_csv (r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\fina_data_in2.csv', index = None, header=True)

# %%
#x = fina_data_in[pd.to_numeric(fina_data_in['DiagnosisGroupCode'], errors='coerce').isnull()]

# %%
#y = fina_data_in.index(fina_data_in['ClmDiagnosisCode_2'].str.contains("V4571"))

# %%
train_final_data=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Final_train2.csv')
train_final_data.head()
# Out:
#    Provider  ClmAdmitDiagnosisCode  DiagnosisGroupCode  ClmDiagnosisCode_1  \
# 0  PRV55912                   7866                 201                1970
# 1  PRV55907                   6186                 750                6186
# 2  PRV56614                  78321                 975                  42
# 3  PRV54090                   5699                 390                1536
# 4  PRV51148                  78605                 379               56212
#
#    ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 0                4019                5853                7843
# 1                2948               56400                   0
# 2                3051               34400                5856
# 3               73300                7230                3659
# 4               25000               30000               73300
#
#    ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7       ...        \
# ...

# %%
train_final_data.shape
# Out:
# (17560, 33)

# %%
train_final_data.describe().transpose()
# Out:
#                                    count          mean           std   min  \
# ClmAdmitDiagnosisCode            17560.0  38033.733371  33120.493196  30.0
# DiagnosisGroupCode               17560.0    423.518565    260.664995   0.0
# ClmDiagnosisCode_1               17560.0  29518.701822  28011.111700  30.0
# ClmDiagnosisCode_2               17560.0  22860.200513  25679.480246   0.0
# ClmDiagnosisCode_3               17560.0  22245.136503  25577.090291   0.0
# ClmDiagnosisCode_4               17560.0  21475.604841  25548.366194   0.0
# ClmDiagnosisCode_5               17560.0  20719.565034  25610.115130   0.0
# ClmDiagnosisCode_6               17560.0  18825.251196  24869.172720   0.0
# ClmDiagnosisCode_7               17560.0  17623.228474  24659.175831   0.0
# ClmDiagnosisCode_8               17560.0  16463.829100  24577.439856   0.0
# ClmDiagnosisCode_9               17560.0  14293.738041  23332.586608   0.0
# ...

# %%
train_predictors = train_final_data[train_final_data.columns[1:32]]
train_predictors.head()
# Out:
#    ClmAdmitDiagnosisCode  DiagnosisGroupCode  ClmDiagnosisCode_1  \
# 0                   7866                 201                1970
# 1                   6186                 750                6186
# 2                  78321                 975                  42
# 3                   5699                 390                1536
# 4                  78605                 379               56212
#
#    ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 0                4019                5853                7843
# 1                2948               56400                   0
# 2                3051               34400                5856
# 3               73300                7230                3659
# 4               25000               30000               73300
#
#    ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7  \
# 0                2768               71590                2724
# 1                   0                   0                   0
# ...

# %%
from sklearn import preprocessing

# %%
train_predictors=preprocessing.scale(train_predictors)
train_predictors=pd.DataFrame(train_predictors)
train_predictors.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.910874 -0.853682 -0.983520 -0.733727 -0.640910 -0.533615 -0.700976
# 1 -0.961599  1.252530 -0.833004 -0.775435  1.335407 -0.840610 -0.809061
# 2  1.216420  2.115731 -1.052352 -0.771424  0.475238 -0.611391  0.859546
# 3 -0.976304 -0.128592 -0.999014  1.964262 -0.587071 -0.697388 -0.697423
# 4  1.224994 -0.170793  0.952981  0.083330  0.303204  2.028540 -0.701054
#
#          7         8         9     ...           21        22        23  \
# 0  2.121753 -0.604223  0.139366    ...     1.658957 -0.769899  0.488941
# 1 -0.756993 -0.714693 -0.669895    ...     1.658957 -0.769899  0.488941
# 2 -0.737450 -0.507097  0.535310    ...    -0.602789 -0.769899  0.488941
# 3 -0.595383 -0.595139 -0.555600    ...    -0.602789  1.298872 -2.045238
# 4  1.377477 -0.599073 -0.489277    ...     1.658957  1.298872  0.488941
#
#          24        25        26        27        28        29        30
# ...

# %%
train_target=train_final_data[['PotentialFraud']]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(criterion='entropy')

# %%
model.fit(train_predictors,train_target)   #DecisionTree model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
preds_train=model.predict(train_predictors)
preds_train=pd.DataFrame(preds_train)
preds_train.head()
# Out:
#    0
# 0  1
# 1  0
# 2  0
# 3  0
# 4  1

# %%
train_final_data['preds_train']=preds_train
train_final_data.head()
# Out:
#    Provider  ClmAdmitDiagnosisCode  DiagnosisGroupCode  ClmDiagnosisCode_1  \
# 0  PRV55912                   7866                 201                1970
# 1  PRV55907                   6186                 750                6186
# 2  PRV56614                  78321                 975                  42
# 3  PRV54090                   5699                 390                1536
# 4  PRV51148                  78605                 379               56212
#
#    ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 0                4019                5853                7843
# 1                2948               56400                   0
# 2                3051               34400                5856
# 3               73300                7230                3659
# 4               25000               30000               73300
#
#    ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7     ...       \
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(train_final_data.PotentialFraud,preds_train)
# Out:
# array([[ 7421,     0],
#        [    0, 10139]], dtype=int64)

# %%
df_in_test=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Test_Inpatientdata-1542969243754.csv')
df_in_test.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt        ...         ClmDiagnosisCode_7  \
# 0            NaN  2009-09-09        ...                       5990
# 1            NaN  2008-12-25        ...                       4549
# ...

# %%
df_bene_test=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Test_Beneficiarydata-1542969243754.csv')
df_op_test=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Test-1542969243754.csv')
df_op_test.head()
# Out:
#    Provider
# 0  PRV51002
# 1  PRV51006
# 2  PRV51009
# 3  PRV51010
# 4  PRV51018

# %%
bene_in_test=pd.merge(df_in_test, df_bene_test, how='left', on='BeneID')
bene_in_test.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt          ...          ChronicCond_Depression  \
# 0            NaN  2009-09-09          ...                               1
# 1            NaN  2008-12-25          ...                               2
# ...

# %%
bene_in_prov_test=pd.merge(bene_in_test, df_op_test, how='left', on='Provider')
bene_in_prov_test.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11014  CLM67387   2009-09-09  2009-09-16  PRV57070
# 1  BENE11017  CLM31237   2008-12-25  2009-01-08  PRV54750
# 2  BENE11026  CLM78930   2009-12-09  2009-12-13  PRV53758
# 3  BENE11031  CLM56810   2009-06-23  2009-07-06  PRV55825
# 4  BENE11085  CLM34625   2009-01-20  2009-01-31  PRV52338
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                    9000          PHY317786          PHY427017
# 1                   14000          PHY314656          PHY426644
# 2                    2000          PHY349495                NaN
# 3                   16000          PHY429538          PHY371893
# 4                   19000          PHY397161                NaN
#
#   OtherPhysician AdmissionDt          ...          ChronicCond_Depression  \
# 0            NaN  2009-09-09          ...                               1
# 1            NaN  2008-12-25          ...                               2
# ...

# %%
bene_in_prov.columns.values
# Out:
# array(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician',
#        'OperatingPhysician', 'OtherPhysician', 'AdmissionDt',
#        'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid', 'DischargeDt',
#        'DiagnosisGroupCode', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
#        'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
#        'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
#        'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1',
#        'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4',
#        'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DOB', 'DOD', 'Gender',
#        'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
# ...

# %%
final_data_in_test=bene_in_prov_test.drop(variables, axis=1)
final_data_in_test.shape
# Out:
# (9551, 32)

# %%
final_data_in_test.columns.values
# Out:
# array(['Provider', 'ClmAdmitDiagnosisCode', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'Gender', 'RenalDiseaseIndicator',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke'], dtype=object)

# %%
final_data_in_test.head()
# Out:
#    Provider ClmAdmitDiagnosisCode DiagnosisGroupCode ClmDiagnosisCode_1  \
# 0  PRV57070                  5789                332               5780
# 1  PRV54750                  5939                661               1889
# 2  PRV53758                  4019                241               4010
# 3  PRV55825                  8208                564               8208
# 4  PRV52338                  4279                880              29654
#
#   ClmDiagnosisCode_2 ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0               5533                496               V420              40390
# 1              41071               5990               5601               4588
# 2              78791              60000              41401              V1254
# 3               4168                920               5990              40391
# 4               V142              78702              30503               V140
#
#   ClmDiagnosisCode_6 ClmDiagnosisCode_7         ...          \
# ...

# %%
cols_test=['Provider', 'ClmAdmitDiagnosisCode', 'DiagnosisGroupCode',
 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
 'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
 'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
 'ClmProcedureCode_6', 'Gender', 'RenalDiseaseIndicator',
 'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
 'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
 'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
 'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
 'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
 'ChronicCond_stroke']

# %%
final_data_in_test[cols_test]=final_data_in_test[cols_test].fillna(0)

# %%
export_final_data_in_test_csv = final_data_in_test.to_csv(r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\final_data_in_test.csv', index = None, header=True)

# %%
test=pd.read_csv(r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\test.csv',encoding='utf-8')

# %%
test['RenalDiseaseIndicator']=test['RenalDiseaseIndicator'].replace('Y',1)
test.head()
# Out:
#    Provider  ClmAdmitDiagnosisCode  DiagnosisGroupCode  ClmDiagnosisCode_1  \
# 0  PRV54750                   5939                 661                1889
# 1  PRV55825                   8208                 564                8208
# 2  PRV57214                    389                 853                 389
# 3  PRV55190                   4359                  32               43491
# 4  PRV54853                  99649                 479                7140
#
#    ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 0               41071                5990                5601
# 1                4168                 920                5990
# 2               51881                2752                5849
# 3               42769               53081                 496
# 4               25000                   0                   0
#
#    ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7  \
# 0                4588                5845                4549
# ...

# %%
test_data=test[test.columns[1:32]]
test_data=preprocessing.scale(test_data)
test_data=pd.DataFrame(test_data)
test_data.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.995434  0.928435 -0.986696  0.693812 -0.632233 -0.609117 -0.618676
# 1 -0.926454  0.558165 -0.760882 -0.722884 -0.827661 -0.594186  0.799421
# 2 -1.164161  1.661342 -1.040300  1.108805 -0.757045 -0.599598  0.892105
# 3 -1.043468 -1.472598  0.499983  0.758997  1.182935 -0.805056 -0.692665
# 4  1.853473  0.233701 -0.799048  0.076850 -0.863123 -0.824093 -0.800399
#
#          7         8         9     ...           21        22        23  \
# 0 -0.530637 -0.535623  0.516747    ...    -0.621063 -0.781626 -2.064855
# 1 -0.646989 -0.547501  0.997941    ...    -0.621063 -0.781626  0.484296
# 2  1.327835 -0.607655 -0.666267    ...    -0.621063 -0.781626  0.484296
# 3  0.854830 -0.571458 -0.586421    ...     1.610143  1.279385  0.484296
# 4 -0.758392 -0.718783 -0.686036    ...    -0.621063 -0.781626  0.484296
#
#          24        25        26        27        28        29        30
# ...

# %%
preds=model.predict(test_data)

# %%
test['predicted_fraud']=preds
test.head()
# Out:
#    Provider  ClmAdmitDiagnosisCode  DiagnosisGroupCode  ClmDiagnosisCode_1  \
# 0  PRV54750                   5939                 661                1889
# 1  PRV55825                   8208                 564                8208
# 2  PRV57214                    389                 853                 389
# 3  PRV55190                   4359                  32               43491
# 4  PRV54853                  99649                 479                7140
#
#    ClmDiagnosisCode_2  ClmDiagnosisCode_3  ClmDiagnosisCode_4  \
# 0               41071                5990                5601
# 1                4168                 920                5990
# 2               51881                2752                5849
# 3               42769               53081                 496
# 4               25000                   0                   0
#
#    ClmDiagnosisCode_5  ClmDiagnosisCode_6  ClmDiagnosisCode_7  \
# 0                4588                5845                4549
# ...

# %%
test=test[['ClmAdmitDiagnosisCode', 'DiagnosisGroupCode',
 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
 'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
 'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
 'ClmProcedureCode_6', 'Gender', 'RenalDiseaseIndicator',
 'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
 'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
 'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
 'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
 'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
 'ChronicCond_stroke','Provider','predicted_fraud']]

# %%
 predicted_fraud= test.to_csv(r'C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\predicted_fraud.csv', index = None, header=True)
