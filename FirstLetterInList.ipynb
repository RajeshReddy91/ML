# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('C:\Users\AG28744\Desktop\Projects\Misc\DS_Datasets\healthcare-provider-fraud-detection-analysis\Train_Inpatientdata-1542865627584.csv')
data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt        ...         ClmDiagnosisCode_7  \
# 0            NaN  2009-04-12        ...                       2724
# 1            NaN  2009-08-31        ...                        NaN
# ...

# %%
y = data['ClmAdmitDiagnosisCode'].tolist()
z=[]
for i in y:#.split()
    if i[0][0] in ['V','E']:
        i[0][0]==0
        z.append(i)
# To get first character of al words in the list

# %%
len(z)
# Out:
# 1202

# %%
for a in z:
    print a
# Out:
# V717
# V553
# V5489
# V5401
# V5789
# V5789
# V5789
# E8889
# V5789
# V5789
# V5789
# V552
# V553
# V5789
# V5789
# V571
# V5789
# V5789
# V5842
# V5789
# V7181
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5811
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V579
# V5789
# V5789
# V5789
# V571
# V5789
# V5789
# V5789
# V5789
# V553
# V5789
# V5811
# V5789
# V5789
# V5789
# V5789
# V553
# V5789
# V5789
# V552
# V5789
# V5789
# V5789
# V5789
# V5789
# V443
# V5789
# V719
# V5789
# V580
# V5789
# V5789
# V5789
# V5789
# V5883
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V560
# V5789
# V553
# V5789
# V553
# V5789
# V5789
# V221
# V5789
# V580
# V5789
# V5789
# V5811
# V5789
# V5789
# V5789
# V5789
# V5789
# V5789
# V553
# V5789
# V5789
# V4581
# V5789
# V5789
# ...

# %%
d=[]
for a in z:
    b=a.split('V')
    b[0]='0'
    c=''.join(b)
    d.append(c)

# %%
d  # check 8th row, its wrong
# Out:
# ['0717',
#  '0553',
#  '05489',
#  '05401',
#  '05789',
#  '05789',
#  '05789',
#  '0',
#  '05789',
#  '05789',
#  '05789',
#  '0552',
#  '0553',
#  '05789',
#  '05789',
#  '0571',
#  '05789',
#  '05789',
#  '05842',
#  '05789',
#  '07181',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05811',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '0579',
#  '05789',
#  '05789',
#  '05789',
#  '0571',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '0553',
#  '05789',
#  '05811',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '0553',
#  '05789',
#  '05789',
#  '0552',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
# ...

# %%
d[0][0]
# Out:
# '0'

# %%
f='abxd'
f.split('E')
# Out:
# ['abxd']

# %%
for a in z:
    b=a.split('V')
    print b
# Out:
# ['', '717']
# ['', '553']
# ['', '5489']
# ['', '5401']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['E8889']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '552']
# ['', '553']
# ['', '5789']
# ['', '5789']
# ['', '571']
# ['', '5789']
# ['', '5789']
# ['', '5842']
# ['', '5789']
# ['', '7181']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5811']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '579']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ['', '571']
# ['', '5789']
# ['', '5789']
# ['', '5789']
# ...

# %%
d=[]
for a in z:
    b=a.split('V')
    if b[0]!='':
        d.append(a)
    else:
        b[0]='0'
        c=''.join(b)
        d.append(c)

# %%
d  # check for o/p with prefix E
# Out:
# ['0717',
#  '0553',
#  '05489',
#  '05401',
#  '05789',
#  '05789',
#  '05789',
#  'E8889',
#  '05789',
#  '05789',
#  '05789',
#  '0552',
#  '0553',
#  '05789',
#  '05789',
#  '0571',
#  '05789',
#  '05789',
#  '05842',
#  '05789',
#  '07181',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05811',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '0579',
#  '05789',
#  '05789',
#  '05789',
#  '0571',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '0553',
#  '05789',
#  '05811',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '0553',
#  '05789',
#  '05789',
#  '0552',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
#  '05789',
# ...

# %%
e=[]
for f in d:
    g=f.split('E')
    g[0]='000'
    h=''.join(g)
    if h!='000':
        e.append(h)

# %%
e
# Out:
# ['0008889']
